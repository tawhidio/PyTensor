# %% [markdown]
# # 포항과 동두천의 각 자료 별 온도변화 분석 그래프
# ***
# * 작성자 : sidcode(Abdullah.Kim) <sidcode@gmail.com>
# * 자료출처 : **[기상자료개방포털(기온분석)]**(https://data.kma.go.kr/stcs/grnd/grndTaList.do?pgmNo=70)
#
# ### 1.포항
#    * 1944년 01월 01일 부터 2020년 12월 09일 까지의 기온변화 자료
#
#
# ### 2. 동두천
#    * 1998년 01월 01일 부터 2020년 12월 07일 까지의 기온변화 자료

# %% [markdown]
# ***
#
# * 포항과 동두천 CSV 파일 읽어 드림
#     * 포항   : pohang_19440717_to_20201209.csv
#     * 동두천 : dongduchun_19980101_to_20201207.csv
#
#
# * 각 지역별 온도변화그래프 처리

# %%
import csv
import matplotlib.pyplot as plt

phohang = open('pohang_19440717_to_20201209.csv', 'r', encoding='cp949')
p_data = csv.reader(phohang)

dongduchun = open('dongduchun_19980101_to_20201207.csv', 'r', encoding='cp949')
d_data = csv.reader(dongduchun)

# %% [markdown]
# ***
# * 포항 데이터 출력
#     * next() 함수를 이용하여 구분 항목 제거
#     * 평균기온, 최저기온, 최고기온 이 모두 존재하는 날만 처리

# %%
next(p_data)

p_n_result = []
p_l_result = []
p_h_result = []
p_date     = []

for prow in p_data :
    if prow[2] != '' and prow[3] != '' and prow[4] != '' :
        if prow[0].split('-')[1] == '07' and prow[0].split('-')[2] == '25' :
            p_n_result.append(float(prow[2])) # 평균기온
            p_l_result.append(float(prow[3])) # 최저기온
            p_h_result.append(float(prow[4])) # 최고기온
            p_date.append(int(prow[0].split('-')[0]))    # 연도
            print(prow)
    
phohang.close()
# Out:
# ['1949-07-25', '138', '24.2', '22.4', '27.6']
# ['1951-07-25', '138', '29.4', '23.7', '36.2']
# ['1952-07-25', '138', '30.4', '24.4', '36.2']
# ['1953-07-25', '138', '29.5', '21.6', '33.6']
# ['1954-07-25', '138', '24.3', '19.5', '29.4']
# ['1955-07-25', '138', '28.2', '25.7', '35.1']
# ['1956-07-25', '138', '25.9', '20.7', '32.4']
# ['1957-07-25', '138', '21.4', '20.8', '22.6']
# ['1958-07-25', '138', '20.9', '19.7', '22.5']
# ['1959-07-25', '138', '23.7', '22.2', '27.1']
# ['1960-07-25', '138', '26', '23.2', '31.1']
# ['1961-07-25', '138', '26.7', '25.3', '28.1']
# ['1962-07-25', '138', '24.7', '21.6', '29.4']
# ['1963-07-25', '138', '25.6', '21.6', '28.5']
# ['1964-07-25', '138', '28.1', '24.4', '31.7']
# ['1965-07-25', '138', '20.5', '18.9', '22.2']
# ['1966-07-25', '138', '28.6', '24.3', '33.2']
# ['1967-07-25', '138', '25.7', '23.9', '28.5']
# ['1968-07-25', '138', '27', '22.8', '31.9']
# ['1969-07-25', '138', '28', '24.1', '33.6']
# ['1970-07-25', '138', '28.4', '22.1', '35.3']
# ['1971-07-25', '138', '22.7', '20.9', '25.2']
# ['1972-07-25', '138', '25.5', '24.3', '28.7']
# ['1973-07-25', '138', '27.4', '21.9', '33.5']
# ['1974-07-25', '138', '20.3', '16.1', '24.8']
# ['1975-07-25', '138', '24.6', '22.6', '30.1']
# ['1976-07-25', '138', '22.8', '21.1', '25.7']
# ['1977-07-25', '138', '29.8', '24.2', '35.9']
# ['1978-07-25', '138', '29.6', '25.7', '35.9']
# ['1979-07-25', '138', '24.5', '23.5', '26.5']
# ['1980-07-25', '138', '23.1', '21', '27.7']
# ['1981-07-25', '138', '27', '23.8', '30.7']
# ['1982-07-25', '138', '22.3', '21.2', '25.2']
# ['1983-07-25', '138', '30.1', '25.8', '34']
# ['1984-07-25', '138', '24.8', '23', '30']
# ['1985-07-25', '138', '29.6', '25.1', '33.9']
# ['1986-07-25', '138', '22.7', '20.2', '25.6']
# ['1987-07-25', '138', '23.2', '22', '25']
# ['1988-07-25', '138', '21.8', '20.8', '23.2']
# ['1989-07-25', '138', '26.7', '25.5', '28.7']
# ['1990-07-25', '138', '28', '25.7', '31']
# ['1991-07-25', '138', '28.7', '26.1', '31.2']
# ['1992-07-25', '138', '30.7', '27.4', '35.8']
# ['1993-07-25', '138', '21.1', '20.3', '21.8']
# ['1994-07-25', '138', '28.2', '26.1', '30.8']
# ['1995-07-25', '138', '28.9', '24.9', '33.6']
# ['1996-07-25', '138', '30.8', '26.7', '35.8']
# ['1997-07-25', '138', '26.4', '22.7', '29.9']
# ['1998-07-25', '138', '22.7', '21.5', '23.8']
# ['1999-07-25', '138', '28.4', '24.2', '34.1']
# ['2000-07-25', '138', '25.8', '23', '32.4']
# ['2001-07-25', '138', '27.2', '25', '30.6']
# ['2002-07-25', '138', '22.7', '21.6', '24.6']
# ['2003-07-25', '138', '20.9', '20', '23.7']
# ['2004-07-25', '138', '27.8', '23.4', '36.2']
# ['2005-07-25', '138', '25.8', '24', '28.3']
# ['2006-07-25', '138', '24.8', '21.7', '29.8']
# ['2007-07-25', '138', '28.8', '23.8', '33.5']
# ['2008-07-25', '138', '21.9', '20.9', '23.3']
# ['2009-07-25', '138', '21', '20.3', '22.1']
# ['2010-07-25', '138', '28.7', '25', '33.6']
# ['2011-07-25', '138', '22.5', '20.7', '24.8']
# ['2012-07-25', '138', '31.3', '26.8', '36']
# ['2013-07-25', '138', '30', '26', '34.2']
# ['2014-07-25', '138', '27.9', '23.2', '34.1']
# ['2015-07-25', '138', '29.6', '26.3', '33.7']
# ['2016-07-25', '138', '27.8', '25.6', '30.9']
# ['2017-07-25', '138', '23.6', '22.7', '24.2']
# ['2018-07-25', '138', '32.2', '27.7', '35.4']
# ['2019-07-25', '138', '28.5', '26.9', '31.1']
# ['2020-07-25', '138', '22.2', '21.1', '24.6']

# %%
print(p_date)
# Out:
# [1949, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %% [markdown]
# ***
# * 그래프 출력

# %%
plt.figure(figsize = (20, 7))
plt.plot(p_date, p_l_result, label="Low")
plt.plot(p_date, p_n_result, 'g', label="Nomal")
plt.plot(p_date, p_h_result, 'r', label="Hight")
plt.legend()
plt.show()

# %% [markdown]
# ***
# * 동두천 데이터 출력
#     * next() 함수를 이용하여 구분 항목 제거
#     * 평균기온, 최저기온, 최고기온 이 모두 존재하는 날만 처리

# %%
next(d_data)

d_n_result = []
d_l_result = []
d_h_result = []
d_date     = []

for drow in d_data :
    if drow[2] != '' and drow[3] != '' and drow[4] != '' :
        if drow[0].split('-')[1] == '07' and drow[0].split('-')[2] == '25' :
            d_n_result.append(float(drow[2]))
            d_l_result.append(float(drow[3]))
            d_h_result.append(float(drow[4]))
            d_date.append(int(drow[0].split('-')[0]))    # 연도
            print(drow)
    
dongduchun.close()
# Out:
# ['1998-07-25', '98', '23.3', '20.2', '30.6']
# ['1999-07-25', '98', '25.8', '23.1', '29.6']
# ['2000-07-25', '98', '24.1', '19.6', '30.6']
# ['2001-07-25', '98', '27.5', '22.7', '33.6']
# ['2002-07-25', '98', '26.8', '20.7', '33.8']
# ['2003-07-25', '98', '26.2', '21.5', '31.2']
# ['2004-07-25', '98', '23.3', '20.4', '27.4']
# ['2005-07-25', '98', '25.8', '22.6', '30.1']
# ['2006-07-25', '98', '23.3', '18', '28.8']
# ['2007-07-25', '98', '23.2', '21.8', '26.1']
# ['2008-07-25', '98', '22.7', '20.8', '27.3']
# ['2009-07-25', '98', '21.8', '18.1', '27']
# ['2010-07-25', '98', '25.3', '22.9', '29.5']
# ['2011-07-25', '98', '23.6', '21.5', '27']
# ['2012-07-25', '98', '27.3', '23.1', '33.5']
# ['2013-07-25', '98', '25.1', '22.1', '29.2']
# ['2014-07-25', '98', '25.9', '21.1', '33.1']
# ['2015-07-25', '98', '24', '23', '25']
# ['2016-07-25', '98', '27.3', '24.9', '31.7']
# ['2017-07-25', '98', '27.4', '22.9', '33.4']
# ['2018-07-25', '98', '28.9', '26.4', '33.2']
# ['2019-07-25', '98', '25.4', '24.6', '26.9']
# ['2020-07-25', '98', '23.7', '21.2', '27.7']

# %%
print(d_date)
# Out:
# [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %% [markdown]
# * 그래프 출력

# %%
plt.figure(figsize = (15, 5))
plt.plot(d_date, d_l_result, label="Low")
plt.plot(d_date, d_n_result, 'g', label="Nomal")
plt.plot(d_date, d_h_result, 'r', label="Hight")
plt.legend()
plt.show()

# %% [markdown]
# * 두 도시의 통합 온도 그래프

# %%
plt.figure(figsize=(20, 7))

# 포항
plt.plot(p_date, p_l_result, label="PL")
plt.plot(p_date, p_n_result, label="PN")
plt.plot(p_date, p_h_result, 'r', label="PH")

# 동두천
plt.plot(d_date, d_n_result, label="DN")
plt.plot(d_date, d_l_result, 'k', label="DL")
plt.plot(d_date, d_h_result, 'y', label="DH")

plt.legend()
plt.show()
