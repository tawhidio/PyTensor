# %% [markdown]
# # 아이리스 품종 예측
# ## 다준분류 문제 해결하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as pl
import numpy as np

# seed 값 설정
np.random.seed(3)
tf.random.set_seed(3)

# 데이터 입력
ds = pd.read_csv('./dataset/iris.csv', names=['Sepal_length', 'Speal_width', 'Petal_length', 'Petal_width', 'Class'])
print(ds.head())                      
print(ds.info())
print(ds.describe())
# Out:
#    Sepal_length  Speal_width  Petal_length  Petal_width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_length  150 non-null    float64
#  1   Speal_width   150 non-null    float64
#  2   Petal_length  150 non-null    float64
#  3   Petal_width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        Sepal_length  Speal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# 그래프 표시
sbn.heatmap(ds.corr(), linewidths='1', cmap="YlGnBu", annot=True, annot_kws={"size":16})
# Out:
# <AxesSubplot:>

# %%
# 그래프로 확인
sbn.pairplot(ds, hue='Class')
pl.show()

# %%
# 데이터 분류
datavalues = ds.values
x = datavalues[:,0:4].astype(float)
y_obj = datavalues[:,4]

# 문자열로 숫자로 변환
e = LabelEncoder()
e.fit(y_obj)
y = e.transform(y_obj)
y_encoded = tf.keras.utils.to_categorical(y)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 실행
model.fit(x, y_encoded, epochs=50, batch_size=1)
# Out:
# Train on 150 samples
# Epoch 1/50
# 150/150 [==============================] - 1s 7ms/sample - loss: 1.3262 - accuracy: 0.3333
# Epoch 2/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.8467 - accuracy: 0.5933
# Epoch 3/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.7125 - accuracy: 0.6800
# Epoch 4/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.6236 - accuracy: 0.7867
# Epoch 5/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.5535 - accuracy: 0.8533
# Epoch 6/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.4985 - accuracy: 0.8667
# Epoch 7/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.4583 - accuracy: 0.9133
# Epoch 8/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.4272 - accuracy: 0.9400
# Epoch 9/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.4006 - accuracy: 0.9200
# Epoch 10/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.3738 - accuracy: 0.9467
# Epoch 11/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.3542 - accuracy: 0.9533
# Epoch 12/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.3366 - accuracy: 0.9600
# Epoch 13/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.3218 - accuracy: 0.9533
# Epoch 14/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.3118 - accuracy: 0.9467
# Epoch 15/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2952 - accuracy: 0.9733
# Epoch 16/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2845 - accuracy: 0.9400
# Epoch 17/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2646 - accuracy: 0.9600
# Epoch 18/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2622 - accuracy: 0.9533
# Epoch 19/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2438 - accuracy: 0.9800
# Epoch 20/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2399 - accuracy: 0.9600
# Epoch 21/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2278 - accuracy: 0.9733
# Epoch 22/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2171 - accuracy: 0.9600
# Epoch 23/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2153 - accuracy: 0.9667
# Epoch 24/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.2010 - accuracy: 0.9800
# Epoch 25/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1987 - accuracy: 0.9733
# Epoch 26/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1890 - accuracy: 0.9867
# Epoch 27/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1821 - accuracy: 0.9733
# Epoch 28/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1771 - accuracy: 0.9733
# Epoch 29/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1706 - accuracy: 0.9733
# Epoch 30/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1664 - accuracy: 0.9667
# Epoch 31/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1590 - accuracy: 0.9800
# Epoch 32/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1509 - accuracy: 0.9600
# Epoch 33/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1529 - accuracy: 0.9800
# Epoch 34/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1446 - accuracy: 0.9733
# Epoch 35/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1455 - accuracy: 0.9733
# Epoch 36/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1389 - accuracy: 0.9667
# Epoch 37/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1339 - accuracy: 0.9733
# Epoch 38/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1340 - accuracy: 0.9733
# Epoch 39/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1306 - accuracy: 0.9800
# Epoch 40/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1243 - accuracy: 0.9800
# Epoch 41/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1257 - accuracy: 0.9733
# Epoch 42/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1220 - accuracy: 0.9600
# Epoch 43/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1179 - accuracy: 0.9667
# Epoch 44/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1171 - accuracy: 0.9667
# Epoch 45/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1222 - accuracy: 0.9600
# Epoch 46/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1138 - accuracy: 0.9733
# Epoch 47/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1098 - accuracy: 0.9733
# Epoch 48/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1080 - accuracy: 0.9600
# Epoch 49/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1075 - accuracy: 0.9667
# Epoch 50/50
# 150/150 [==============================] - 0s 2ms/sample - loss: 0.1050 - accuracy: 0.9667

# %%
# 결과 출력
print("\n Accuracy : %.4f"%(model.evaluate(x, y_encoded)[1]))
# Out:
# 150/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#
#  Accuracy : 0.9733
