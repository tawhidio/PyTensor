# %% [markdown]
# <script type="text/javascript" src="http://cdn.mathjax.org/mathjax/latest/MathJax.js?config=default"></script>
# # 공부시간과 성적의 관계
#
# |공부시간|성적|예측값|
# |:---:|:---:|:---:|
# |2|81|**83.6**|
# |4|93|**88.2**|
# |6|91|**92.8**|
# |8|97|**97.4**|
#
# # fake_a_b는 임의의 예측값을 넣으면된다
# # 아래는 공식으로 순차적으로 풀기위해
# # 기본에서 계산처리한값들
#
# ##  공식
# * $ 공부시간(x) 평균 : (2 + 4 + 6 + 8) / 4 = 5 $
# * $ 성적(y) 평균     : (81 + 93 + 91 + 97) / 4 = 90.5 $
# ### 1.  $ 기울기 a = {(x - x평균)(y - y평균)의 합     \over (x - x평균)^2의 합    } $
# ==> $ a = {(2-5)(81-90.5)+(4-5)(93-90.5)+(6-5)(91-90.5)+(8-5)(97-90.5) \over ((2-5)^2+(4-5)^2+(6-5)^2+(8-5)^2} $
# ===> $ {46 \over 20} $
# ====> $ 기울기 a = 2.3 $
# ### 2 . $ y절편의 값 b = y의 평균 - (x의 평균 \times 기울기 a) $
# ==> $ b = 90.5 - (5 \times 2.3) $
# ===> $ b = 90.5 - 11.5 $
# ====> $ y절편의 값 b = 79 $
# ### 3. $ y = ax + b $
# ==> $ y = 2.3x + 79 $
# ===> $y = 2.3 \times 2 + 79  = 83.6 $
# ===> $y = 2.3 \times 4 + 79  = 88.2 $
# ===> $y = 2.3 \times 6 + 79  = 82.8 $
# ===> $y = 2.3 \times 8 + 79  = 87.4 $
# ### 4.$ 오차 값 $
# ==> $ 오차 = 예측값 - 실제값 $
# ===> $ 83.6 - 81 = 1.0 $
# ===> $ 88.2 - 93 = 25.0 $
# ===> $ 92.8 - 91 = 9.0 $
# ===> $ 97.4 - 97 = 9.0 $
# ### 5 $ 평균 제곱 오차(MSE) $
# ==> $ \sum\limits_{i}^n (\hat{y_i} - y_i)^2 $
# ===> $ (83.6 - 81)^2 = 6.7599999999999705   $
# ===> $ (88.2 - 93)^2 = 23.039999999999974   $
# ===> $ (92.8 - 91)^2 = 3.2399999999999896   $
# ===> $ (97.4 - 97)^2 = 0.16000000000000456  $
# ==> $ \frac{1}{n}\sum (\hat{y_i} - y_i)^2   $
#  > $ (6.7599999999999705 + 23.039999999999974 + 3.2399999999999896 + 0.16000000000000456) / 4 $
#  > $ 평균 제곱 오차(MSE) = 8.299999999999985 $

# %%
import numpy as np
import matplotlib.pyplot as pl


# 공부 시간X , 성적Y 리스트 생성 
# i[0] = [2, 4, 6, 8]
# i[1] = [81, 93, 91, 97]
data = [[2, 0, 81], [4, 4, 93], [6, 2, 91], [8, 3, 97]]
x1 = [i[0] for i in data]
x2 = [i[1] for i in data]
y = [i[2] for i in data]

print("x1 => ", x1)
print("x2 => ", x2)
print("y => ", y)
# Out:
# x1 =>  [2, 4, 6, 8]
# x2 =>  [0, 4, 2, 3]
# y =>  [81, 93, 91, 97]

# %%
#그래프로 확인해 봅니다.
ax = pl.axes(projection='3d')
ax.set_xlabel('study_hours')
ax.set_ylabel('private_class')
ax.set_zlabel('Score')
ax.dist = 11 
ax.scatter(x1, x2, y)
pl.show()

# %%
# 리스트 ==> 배열 각 개별 처리 위함
x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)
           
print("x1_data => ", x1_data)
print("x2_data => ", x2_data)
print("y_data => ", y_data)

# 기울기 a와 y의 절편 b의 값 초기화
a1 = 0
a2 = 0
b = 0

# 학습진행률
lr = 0.01

# 반복횟수
epochs = 20001

# 이해를 돕기위한 단순 출력
ex_y_pred = (a1 + lr) * x1_data + (a2 + lr) * x2_data + b
print("y_pred_공식 => ", ex_y_pred)
ex_y_pred = (a1 + lr) * x1_data + (a2 + lr) * x2_data + 81 # 2 * 2 + 81...
print("y_pred_실제값대입경우=> ", ex_y_pred)
ex_y_pred = (a1 + lr) * x1_data + (a2 + lr) * x2_data + 81 # 2 * 2 + 81...
print("y_pred_실제값대입경우=> ", ex_y_pred)
ex_error = y_data - ex_y_pred # 오차 값 [ 실제값 - 예측 값]
print("ex_error=> ", ex_error)
# Out:
# x1_data =>  [2 4 6 8]
# x2_data =>  [0 4 2 3]
# y_data =>  [81 93 91 97]
# y_pred_공식 =>  [0.06 0.24 0.24 0.33]
# y_pred_실제값대입경우=>  [81.06 81.24 81.24 81.33]
# y_pred_실제값대입경우=>  [81.06 81.24 81.24 81.33]
# ex_error=>  [-0.06 11.76  9.76 15.67]

# %%
# 몇 세대를 진행 할것인가.
for i in range(epochs):
    y_pred = a1 * x1_data  + a2 * x2_data + b # 예측값 [ y = ax + b ]
    error = y_data - y_pred # 오차 값 [ 실제값 - 예측 값]
    
    # 평균제곱 오차를 a로 편미분한 결과
    a1_diff = -(2/len(x1_data)) * sum(x1_data * (error))
    a2_diff = -(2/len(x2_data)) * sum(x2_data * (error))
    # 평균제곱 오차를 b로 편미분한 결과
    b_diff = -(2/len(x1_data)) * sum(error)
    
    a1 = a1 - lr * a1_diff # 학습률을 곱해 기존의 a1값을 업데이트 
    a2 = a2 - lr * a2_diff # 학습률을 곱해 기존의 a2값을 업데이트 
    b = b - lr * b_diff # 학습률을 곱채 기존의 b값을 업데이트
    
    if i%100 == 0: # 백번 반복될때 마다 현재의 a값 b값 출력
        print("a1_diff = %.07f, a2_diff = %.07f, b_diff = %.07f " %(a1_diff, a2_diff, b_diff))
        print("epoch = %.f, 기울기a1 = %.07f, 기울기a2 = %.07f, 절편 = %.07f"%(i, a1, a2, b))
# Out:
# a1_diff = 928.0000000, a2_diff = 422.5000000, b_diff = 181.0000000
# epoch = 0, 기울기a1 = -27.8400000, 기울기a2 = -12.6750000, 절편 = -5.4300000
# a1_diff = 350062722590010148673797897922593452714779734924328960.0000000, a2_diff = 158815944430805161103744889977301431477548812223905792.0000000, b_diff = 58971527280890460929128430953078643363458294696902656.0000000
# epoch = 100, 기울기a1 = -15265920531383157434487178282332805544766734797373440.0000000, 기울기a2 = -6925820518275380209516612548365354780701195501568000.0000000, 절편 = -2571695273417434433429305122086071687855356541665280.0000000
# a1_diff = 131497082546245184521325104868251139564084720541387880637582299960839292126919405502091421107906393669632.0000000, a2_diff = 59657404250198902388579237407739340846654328781582595019592694352472445754540059189088635819094926426112.0000000, b_diff = 22151983888371604389270279790504877019992062980880740153225094172728984512453913088890781306046967185408.0000000
# epoch = 200, 기울기a1 = -5734469518511927431133799527270824718566367263226685620012805224207330406914473207803400112979899842560.0000000, 기울기a2 = -2601605751260662256344772354628513184067059347757990806872618273782723040467509278613211273513301704704.0000000, 절편 = -966028096766026384902435264087397712145599917150388064868044059007736359167290705896886038355305824256.0000000
# a1_diff = 49395384319242812907410702076098451160949072490587879896042011052799884254518033353936854616099657822743641078371161490235448439493501346596581420738543616.0000000, a2_diff = 22409625775466673590872156699269332897531770547564684880277388574530235147750692499455113307310843819565959185879037692066422877150148807250117910130065408.0000000, b_diff = 8321140944058417207210519217062879292611548724944104217925956623724266770388789864401288332687308673979182452299800944457398690487516739549661595070103552.0000000
# epoch = 300, 기울기a1 = -2154088290394303748381520915201538217874453535335606530917260459819375702433183643647276302073046920557975923809947290211206213199759327579381173095235584.0000000, 기울기a2 = -977263627772723345514900473770009342514045308169434643830676348594437296193951598142606362281312093692971905218864114245224596305270805068581826872737792.0000000, 절편 = -362877473621235858470569784103331705079295444741206887129045794189596729893443634051752153760504628555331330303177183540394224373326536752540714551738368.0000000
# a1_diff = 18554814637713559673693334996877485320998407740132538806710873458406572613966732220754196764149695920467953497133135813510367348064217718535718811851449853732191117821633886796137378689380605382600247214080.0000000, a2_diff = 8417921190306996991508321477602300805326324607556114335176089866538460747505542941368113881169596214604252638528019809556140473451355874804965475771371018697831997319242635377485975588933257802429658824704.0000000, b_diff = 3125742008472331436351193428567152314276191271390784620606420252859763636717319161758437816057022507788238593105399844001704405773359427778631045164796254503422864836524514186521960109780602615143711375360.0000000
# epoch = 400, 기울기a1 = -809158780569809498747135311102209861040197500306025352081897763072941091153568362300799751600443982934090601640357211168225127901609797742439909594245648895012798648679058286755672955384195082573160906752.0000000, 기울기a2 = -367097973128602323726679677849507484735287622279255394817485426739988468651334603562072731592160120860736079523214080210982310624567271018625420716635747487155278715819494923050972024099695950470666256384.0000000, 절편 = -136310798104688872455956780691504522543776344420423984326769140475099575837578256309891640698098150486703458862695041185828962029872085050809752555401652744424671492501297394816524646864810571386857717760.0000000
# a1_diff = .0000000, a2_diff = .0000000, b_diff = .0000000
# epoch = 500, 기울기a1 = -303951298139860313138462603429679684114304165501880979497445231546296260396418726998678914120633922362415980336390831152572403412905398338162346436792560577741815962761195080846479617173503635057356225701811236118441218283109370421539477066526951947108352.0000000, 기울기a2 = -137896180769830712243708701938850770872162300395832470087759413840249097225212473090929402428736600074378056880972613809944036105460771983295010341036615806395293563300605596639766339345875672891081527402042823730929556199714925184159709403127492852580352.0000000, 절편 = -51203601850831180174840822421089722500990481250618617041341202976742173648343412659437177883515206901209001718861861683941914319845080053366880060301947469715684356728778646904780360709048052705002107728825380286403383930221215034214700256358449117396992.0000000
# a1_diff = .0000000, a2_diff = .0000000, b_diff = .0000000
# epoch = 600, 기울기a1 = -.0000000, 기울기a2 = -.0000000, 절편 = -.0000000
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 1900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 2900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 3900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 4900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 5900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 6900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 7900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 8900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 9800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# D:\Anaconda3\envs\pytensor\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in multiply
#   import sys
# D:\Anaconda3\envs\pytensor\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in double_scalars
#   import sys
# D:\Anaconda3\envs\pytensor\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in double_scalars
#
# D:\Anaconda3\envs\pytensor\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in multiply
#   This is separate from the ipykernel package so we can avoid doing imports until
# epoch = 9900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 10900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 11900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 12900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 13900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 14900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 15900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 16900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 17900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 18900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19100, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19200, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19300, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19400, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19500, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19600, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19700, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19800, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 19900, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
# a1_diff = nan, a2_diff = nan, b_diff = nan
# epoch = 20000, 기울기a1 = nan, 기울기a2 = nan, 절편 = nan
